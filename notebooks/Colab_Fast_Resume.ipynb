# %% [markdown]
# # ⚡ MiniGPT: Fast Resume & Training (Pro Mode)
#
# Use this notebook if you have **already** processed your 10GB data and saved it to Google Drive.
#
# ### ⚡ Key Features:
# - **Zero Data Download**: Links directly to your Drive data.
# - **Automatic Resume**: Picks up exactly where your last training session left off.
# - **Modern Architecture**: RoPE, RMSNorm, SwiGLU enabled.

# %% [markdown]
# ## 🛠️ Step 0: Setup & Linking
# Connect to Drive and link your persistent data/checkpoints.

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# 1. Setup Project
if not os.path.exists('MiniGPT-from-Scratch'):
    # !git clone https://github.com/mrshibly/MiniGPT-from-Scratch.git

# %cd MiniGPT-from-Scratch
# !git pull
# !pip install -r requirements.txt

# 2. Link Data from Drive (Instant)
# !mkdir -p data/processed data/tokenizer
# !ln -s /content/drive/MyDrive/MiniGPT_Data/*.bin data/processed/
# !ln -s /content/drive/MyDrive/MiniGPT_Data/tokenizer.json data/tokenizer/

# 3. Link Checkpoints from Drive
# !rm -rf checkpoints
# !ln -s /content/drive/MyDrive/MiniGPT_Checkpoints checkpoints

print("✅ Project, Data, and Checkpoints linked successfully!")

# %% [markdown]
# ## 🚀 Step 1: Start/Resume Training
# Training will automatically resume from `checkpoints/ckpt.pt` if it exists in your Drive.

# %%
# !python src/train/train.py

# %% [markdown]
# ## 📝 Step 2: Test the Model
# Launch the Gradio demo to see the latest progress.

# %%
# !python app.py --share
